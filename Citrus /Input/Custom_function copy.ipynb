# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Segmented_10cycles_Eggs_Day7_Batch_8_Calls_H3O_EN113_set1.csv")

# %%
data
# Out:
#                             group_id  Unnamed: 1     AbsTime    RelTime  \
# 0                          Jar_BLK_1          84  44841.7307    84.0001
# 1                          Jar_BLK_1          85  44841.7307    85.0001
# 2                          Jar_BLK_1          86  44841.7307    86.0001
# 3                          Jar_BLK_1          87  44841.7307    87.0001
# 4                          Jar_BLK_1          88  44841.7307    88.0001
# ..                               ...         ...         ...        ...
# 567                        Jar_BLK_4        7670  44841.8186  7679.6457
# 568                        Jar_BLK_4        7671  44841.8186  7680.6457
# 569                        Jar_BLK_4        7672  44841.8186  7681.6457
# 570                        Jar_BLK_4        7673  44841.8186  7682.6457
# 571                        Jar_BLK_4        7674  44841.8186  7683.6457
#
#      Cycle  m15.881 (B_m15.881) (Corr)  m16.214 (B_m16.214) (Corr)  \
# ...

# %%
def mymean(col):
    return np.mean(col)

data.groupby(['group_id']).mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-78b0d37e56db> in <module>
#       2     return np.mean(col)
#       3
# ----> 4 data.groupby(['group_id']).mean()
#
# NameError: name 'data' is not defined

# %%
def mymean(col):
    return np.mean(col)
    

data.groupby(by="group_id").apply(mymean)
#data.groupby(["group_id"]).apply(lambda x: np.mean(x))


#(data
#     .groupby("group_id")3     .pipe(pd.DataFrame.mean, 0)
#)
#apply(np.mean, axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b3acca229289> in <module>
#       3
#       4
# ----> 5 data.groupby(by="group_id").apply(mymean)
#       6 #data.groupby(["group_id"]).apply(lambda x: np.mean(x))
#       7
#
# NameError: name 'data' is not defined

# %%
def mymean(col):
    return np.mean(col)
    
data.groupby(["group_id"]).apply(lambda x: np.mean(x)).reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-019ec8b3a5ca> in <module>
#       2     return np.mean(col)
#       3
# ----> 4 data.groupby(["group_id"]).apply(lambda x: np.mean(x)).reset_index()
#
# NameError: name 'data' is not defined

# %%
def mymean(col):
    return np.mean(col)

data.groupby(['group_id']).mean()
# Out:
#                                  Unnamed: 1       AbsTime      RelTime  \
# group_id
#                       Jar_BLK_1        89.0  44841.730727    89.000100
#                       Jar_BLK_2      4176.0  44841.778145  4185.643300
#                       Jar_BLK_3      4854.0  44841.785982  4863.643700
#                       Jar_BLK_4      7669.0  44841.818564  7678.645700
# 1                                      49.0  44841.730255    49.000000
# 10                                   2102.0  44841.754136  2111.641800
# 11                                   2296.0  44841.756373  2305.641900
# 12                                   2457.0  44841.758245  2466.642000
# 13                                   2621.0  44841.760145  2630.642100
# 14                                   2812.0  44841.762355  2821.642300
# 15                                   2913.0  44841.763527  2922.642300
# 16                                   3099.0  44841.765673  3108.642500
# ...

# %%
df.groupby(['groupcol']).mean().unstack() OR df.groupby(['groupcol']).apply(lambda x: np.mean(x)).unstack()
# Out:
#   File "<ipython-input-7-536e9ff3bc27>", line 1
#     df.groupby(['groupcol']).mean().unstack() OR df.groupby(['groupcol']).apply(lambda x: np.mean(x)).unstack()
#                                               ^
# SyntaxError: invalid syntax

# %%
def mymean(col):
    return np.mean(col)

# %%
data.groupby(['group_id']).mean()   #.reset_index() :  dataframe.groupby(['id']).apply(lambda x: np.mean(x)).reset_index()  #.unstack() OR df.groupby(['groupcol']).apply(lambda x: np.mean(x)).unstack()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dbadeb47c642> in <module>
# ----> 1 data.groupby(['group_id']).mean()   #.reset_index() :  dataframe.groupby(['id']).apply(lambda x: np.mean(x)).reset_index()  #.unstack() OR df.groupby(['groupcol']).apply(lambda x: np.mean(x)).unstack()
#
# NameError: name 'data' is not defined
